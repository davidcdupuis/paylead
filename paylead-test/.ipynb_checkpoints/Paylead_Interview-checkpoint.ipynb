# %% [markdown]
# # Python Interview Test
#
# **Objective:** Build an alerting/warning system when the sales of a store leave a "normal" range. The system can only depend on past data and the "intelligence" depends on determining the sales threshold.
#
# We'll suppose that there are two types of warnings possible:
# * Sales are too low. The store isn't performing as well as it should be. This is the most obvious one.
# * Sales are "too high". Can sales really be too high? If at a given moment in time, sales are too good this may either indicate an error or that "something great happened". We can assume that any store manager will want to know what that "something great happened" is and if it can be reproduced.
#
# **Approach:** The system is time based, a stream of a data is coming into our system. At time *t*, it must decide whether the sales of the store are in or outside the "normal" range based on all of the sales information before time *t*. Therefore, we are facing with a streaming algorithm. This stream evolves every 24 hours so we suppose that we have plenty of time between each date to update our decisional parameters.
#
# **Solutions:**
# * We can code a function which reads the stream, updates parameters dynamically and decides whether Sales are outliers. This is a simplistic approach which may not consider the relationship between variables.
# * A better approach is to code a Time series classification algorithm which predicts 2 or 3 possible categories:
#     * 2 => good or bad
#     * 3 => bad, ok, too good
#
#     However, we don't have the time to code such a time series classification algorithm.

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Analysis
#
# In order to decide which properties are worth recording we must analyze our dataset.

# %%
data = pd.read_csv("train.csv")
data.sort_values(by='Date',inplace=True)
data.head()
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1017208   1115          2  2013-01-01      0          0     0      0
# 1016473    379          2  2013-01-01      0          0     0      0
# 1016472    378          2  2013-01-01      0          0     0      0
# 1016471    377          2  2013-01-01      0          0     0      0
# 1016470    376          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1017208            a              1
# 1016473            a              1
# 1016472            a              1
# 1016471            a              1
# 1016470            a              1

# %%
print("Rows: {}, Attributes: {}\n".format(data.shape[0], data.shape[1]))
# Out:
# Rows: 1017209, Attributes: 9

# %%
print(data.groupby('Store').size())
# Out:
# Store
# 1       942
# 2       942
# 3       942
# 4       942
# 5       942
# 6       942
# 7       942
# 8       942
# 9       942
# 10      942
# 11      942
# 12      942
# 13      758
# 14      942
# 15      942
# 16      942
# 17      942
# 18      942
# 19      942
# 20      758
# 21      942
# 22      758
# 23      942
# 24      942
# 25      942
# 26      942
# 27      942
# 28      942
# 29      942
# 30      942
#        ...
# 1086    942
# 1087    942
# 1088    942
# 1089    942
# 1090    942
# 1091    942
# 1092    758
# 1093    942
# 1094    758
# 1095    942
# 1096    942
# 1097    942
# 1098    942
# 1099    942
# 1100    942
# 1101    942
# 1102    758
# 1103    942
# 1104    758
# 1105    942
# 1106    942
# 1107    758
# 1108    942
# 1109    758
# 1110    942
# 1111    942
# 1112    942
# 1113    942
# 1114    942
# 1115    942
# dtype: int64

# %%
stores = pd.read_csv("store.csv")
stores.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
print("Rows: {}, Attributes: {}\n".format(stores.shape[0], stores.shape[1]))
# Out:
# Rows: 1115, Attributes: 10

# %%
print(stores.groupby("StoreType").size())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-2454d656efb7> in <module>()
# ----> 1 print(stores.groupby("StoreType").size())
#
# NameError: name 'stores' is not defined

# %% [markdown]
# We'll want to merge train_dataset and store_dataset in order to have the proper data throughout the stream.

# %%
data.groupby("Store")["Sales"].mean()
# Out:
# Store
# 1        3945.704883
# 2        4122.991507
# 3        5741.253715
# 4        8021.769639
# 5        3867.110403
# 6        4562.375796
# 7        7356.902335
# 8        4610.251592
# 9        5426.816348
# 10       4634.439490
# 11       6683.955414
# 12       6316.608280
# 13       4124.773087
# 14       4555.386412
# 15       5553.619958
# 16       6335.340764
# 17       5259.541401
# 18       5446.005308
# 19       5346.251592
# 20       6334.489446
# 21       4522.041401
# 22       3695.918206
# 23       4565.073248
# 24       7763.773885
# 25       8892.311040
# 26       5538.498938
# 27       7838.438429
# 28       4332.218684
# 29       6090.403397
# 30       4367.352442
#             ...
# 1086     6365.240977
# 1087     5228.500000
# 1088     4204.866242
# 1089     8402.582803
# 1090     5343.307856
# 1091     6888.168790
# 1092     9814.584433
# 1093     6904.761146
# 1094     3753.922164
# 1095     3969.285563
# 1096     4512.348195
# 1097     9744.599788
# 1098     4354.997877
# 1099     7340.338641
# 1100     4423.963907
# 1101     8299.635881
# 1102     5744.054090
# 1103     4161.639066
# 1104     4481.546174
# 1105     3774.736730
# 1106     4073.217622
# 1107     5121.849604
# 1108     4758.597665
# 1109     4043.167546
# 1110     3766.970276
# 1111     4342.968153
# 1112     8465.280255
# 1113     5516.180467
# 1114    17200.196391
# 1115     5225.296178
# Name: Sales, dtype: float64

# %%
data.groupby("Store")["Sales"].std()
# Out:
# Store
# 1       2015.417823
# 2       2363.628566
# 3       3298.782503
# 4       4012.592803
# 5       2389.609801
# 6       2527.359294
# 7       3969.299812
# 8       2696.883757
# 9       2891.687915
# 10      2291.820892
# 11      3632.841037
# 12      3400.997795
# 13      2429.243915
# 14      2481.297443
# 15      2901.965024
# 16      3394.545036
# 17      3292.925143
# 18      2952.044038
# 19      2965.209099
# 20      3371.801447
# 21      2644.161304
# 22      2032.834720
# 23      2548.811488
# 24      4270.307717
# 25      5151.671962
# 26      3105.701531
# 27      4460.597269
# 28      2819.430616
# 29      3433.366424
# 30      2452.841210
#            ...
# 1086    4016.159484
# 1087    2660.400534
# 1088    2412.341808
# 1089    4368.694084
# 1090    3250.724381
# 1091    3684.588444
# 1092    4898.236111
# 1093    3608.976586
# 1094    1985.545013
# 1095    2179.436395
# 1096    2508.102869
# 1097    1900.891896
# 1098    2500.697503
# 1099    2693.167095
# 1100    2783.419120
# 1101    4381.646608
# 1102    2922.481309
# 1103    2305.546573
# 1104    2395.521655
# 1105    2246.662413
# 1106    2225.354129
# 1107    3004.517099
# 1108    3105.518153
# 1109    2274.921098
# 1110    2142.773203
# 1111    2500.008800
# 1112    4919.925304
# 1113    2811.389336
# 1114    8343.045607
# 1115    2847.822677
# Name: Sales, dtype: float64

# %%
data.groupby("Store")["Sales"].var()
# Out:
# Store
# 1        4061909
# 2        5586740
# 3       10881966
# 4       16100901
# 5        5710235
# 6        6387545
# 7       15755341
# 8        7273182
# 9        8361859
# 10       5252443
# 11      13197534
# 12      11566786
# 13       5901226
# 14       6156837
# 15       8421401
# 16      11522936
# 17      10843356
# 18       8714564
# 19       8792465
# 20      11369045
# 21       6991589
# 22       4132417
# 23       6496440
# 24      18235528
# 25      26539724
# 26       9645382
# 27      19896928
# 28       7949189
# 29      11788005
# 30       6016430
#           ...
# 1086    16129537
# 1087     7077731
# 1088     5819393
# 1089    19085488
# 1090    10567209
# 1091    13576192
# 1092    23992717
# 1093    13024712
# 1094     3942389
# 1095     4749943
# 1096     6290580
# 1097     3613390
# 1098     6253488
# 1099     7253149
# 1100     7747422
# 1101    19198827
# 1102     8540897
# 1103     5315545
# 1104     5738524
# 1105     5047492
# 1106     4952201
# 1107     9027123
# 1108     9644243
# 1109     5175266
# 1110     4591477
# 1111     6250044
# 1112    24205665
# 1113     7903910
# 1114    69606410
# 1115     8110094
# Name: Sales, dtype: int64

# %% [markdown]
# ## Solution 1
#
# **Description:** Our simple function is going to read the stream and record the sales for each store when the store is open. It will compute the mean and the standard deviation on the recorded data. For each new entry we are going to check the **Sales** value if it's beyond 2-standard deviations of the mean we'll print a "Warning" message.
#
# * If the store is closed we don't bother.
#
# **Validating:** To validate our solution we can use the analysis of the entire dataset to determine atemporarily which sales are beyong "normal". This will give us an idea of the performance of our decision making.

# %%
global_stores = pd.concat([data.groupby("Store")["Sales"].mean(),],axis=1,keys=["mean","std"])
global_stores.head()
# Out:
#               mean          std
# Store
# 1      3945.704883  2015.417823
# 2      4122.991507  2363.628566
# 3      5741.253715  3298.782503
# 4      8021.769639  4012.592803
# 5      3867.110403  2389.609801

# %%
global_stores["mean"][335] - 2 * global_stores["std"][335]
# Out:
# 3789.2324608307244

# %%
# record stream information
local_mean = [0 for x in range(stores.size)]
local_std = [0 for x in range(stores.size)]

# %%
record = {}
for i in range(stores.size):
    record[i] = []

# %%
stream = pd.concat([data["Date"], data["Store"],data["Sales"],data["Open"]],axis=1)
stream.head()
# Out:
#                Date  Store  Sales  Open
# 1017208  2013-01-01   1115      0     0
# 1016473  2013-01-01    379      0     0
# 1016472  2013-01-01    378      0     0
# 1016471  2013-01-01    377      0     0
# 1016470  2013-01-01    376      0     0

# %%
def readStream(stream):
    for index, row in data.iterrows():
        if(row["Open"] == 1):
            # check if local outlier
            if(row['Sales'] < local_mean[row["Store"]]- 2 * local_std[row["Store"]]):
                print("Negative Local Outlier Warning: [date: {}, store: {}, sales: {}]".format(row['Date'],row['Store'],row['Sales']))
            elif (row['Sales'] < local_mean[row["Store"]]- 2 * local_std[row["Store"]]):
                print("Positive Local Outlier Warning: [date: {}, store: {}, sales: {}]".format(row['Date'],row['Store'],row['Sales']))
            
            # check if global outlier 
            #if(row['Sales'] < global_stores["mean"][row["Store"]] - 2 * global_stores["std"][row["Store"]]):
            #    print("Negative Global Outlier Warning: [date: {}, store: {}, sales: {}]".format(row['Date'],row['Store'],row['Sales']))
            #elif (row['Sales'] > global_stores["mean"][row["Store"]] + 2 * global_stores["std"][row["Store"]]):
            #    print("Positive Global Outlier Warning: [date: {}, store: {}, sales: {}]".format(row['Date'],row['Store'],row['Sales']))

            # record values
            record[row['Store']].append(row['Sales'])
            local_mean[row['Store']] = np.mean(np.array(record[row['Store']]))
            local_std[row['Store']] = np.std(np.array(record[row['Store']]))
            # recompute mean and std for store

# %%
readStream(stream)
# Out:
# Negative Local Outlier Warning: [date: 2013-01-01, store: 494, sales: 3113]
# Negative Local Outlier Warning: [date: 2013-01-01, store: 682, sales: 3375]
# Negative Local Outlier Warning: [date: 2013-01-01, store: 562, sales: 8498]
# Negative Local Outlier Warning: [date: 2013-01-01, store: 769, sales: 5035]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 381, sales: 3964]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 401, sales: 2273]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 396, sales: 4325]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 306, sales: 2200]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 332, sales: 1224]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 432, sales: 6456]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 483, sales: 1375]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 479, sales: 5261]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 476, sales: 2385]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 454, sales: 1938]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 460, sales: 981]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 462, sales: 2170]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 88, sales: 1870]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 133, sales: 3603]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 123, sales: 3626]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 121, sales: 2225]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 110, sales: 2396]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 28, sales: 2070]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 20, sales: 3642]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 5, sales: 1590]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 14, sales: 2519]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 138, sales: 2578]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 257, sales: 2997]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 933, sales: 2869]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 932, sales: 3671]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 921, sales: 4913]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 970, sales: 1303]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 958, sales: 2950]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 864, sales: 2027]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 898, sales: 1870]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 876, sales: 2224]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 1065, sales: 1864]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 1032, sales: 5067]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 1030, sales: 1128]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 1029, sales: 1651]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 837, sales: 1014]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 617, sales: 2373]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 786, sales: 660]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 817, sales: 15442]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 700, sales: 1479]
# Negative Local Outlier Warning: [date: 2013-01-05, store: 709, sales: 3541]
# Negative Local Outlier Warning: [date: 2013-01-06, store: 310, sales: 2334]
# Negative Local Outlier Warning: [date: 2013-01-06, store: 863, sales: 2067]
# Negative Local Outlier Warning: [date: 2013-01-06, store: 578, sales: 3395]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 364, sales: 1621]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 315, sales: 1863]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 423, sales: 6168]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 432, sales: 6443]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 454, sales: 1927]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 483, sales: 1269]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 134, sales: 2916]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 121, sales: 2234]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 59, sales: 2273]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 257, sales: 2533]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 935, sales: 2638]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 933, sales: 2925]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 918, sales: 2131]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 921, sales: 4720]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 968, sales: 3372]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 953, sales: 1979]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 958, sales: 2734]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 852, sales: 2526]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 873, sales: 2106]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 1035, sales: 1547]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 1029, sales: 1477]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 688, sales: 1340]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 583, sales: 2205]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 837, sales: 1179]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 569, sales: 2648]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 622, sales: 2131]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 786, sales: 735]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 817, sales: 15156]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 700, sales: 1252]
# Negative Local Outlier Warning: [date: 2013-01-12, store: 709, sales: 3386]
# Negative Local Outlier Warning: [date: 2013-01-13, store: 310, sales: 1703]
# Negative Local Outlier Warning: [date: 2013-01-13, store: 530, sales: 1087]
# Negative Local Outlier Warning: [date: 2013-01-13, store: 578, sales: 3230]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 352, sales: 4114]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 281, sales: 3482]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 482, sales: 4963]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 75, sales: 3859]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 221, sales: 3253]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 267, sales: 5706]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 1070, sales: 4089]
# Negative Local Outlier Warning: [date: 2013-01-14, store: 772, sales: 1920]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 380, sales: 7841]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 354, sales: 3435]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 359, sales: 3988]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 415, sales: 3205]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 414, sales: 3855]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 334, sales: 3090]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 323, sales: 4442]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 521, sales: 2423]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 515, sales: 4713]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 541, sales: 3671]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 527, sales: 5722]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 421, sales: 5075]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 431, sales: 5390]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 90, sales: 4622]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 75, sales: 3936]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 31, sales: 3626]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 9, sales: 2724]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 228, sales: 3526]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 213, sales: 3311]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 214, sales: 4226]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 169, sales: 4212]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 158, sales: 4478]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 199, sales: 3230]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 194, sales: 2955]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 922, sales: 4180]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 961, sales: 4218]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 888, sales: 4374]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 1037, sales: 4125]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 653, sales: 2551]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 586, sales: 7414]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 564, sales: 2733]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 600, sales: 3601]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 800, sales: 3274]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 799, sales: 5726]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 832, sales: 3641]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 810, sales: 3354]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 738, sales: 3707]
# Negative Local Outlier Warning: [date: 2013-01-15, store: 742, sales: 3866]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 373, sales: 2317]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 356, sales: 2881]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 394, sales: 4558]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 342, sales: 7439]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 492, sales: 4820]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 550, sales: 2591]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 450, sales: 4782]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 428, sales: 3608]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 108, sales: 6445]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 56, sales: 4155]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 40, sales: 2694]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 49, sales: 2580]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 239, sales: 1725]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 154, sales: 4146]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 174, sales: 3646]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 182, sales: 2253]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 1114, sales: 13763]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 868, sales: 6036]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 865, sales: 3227]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 845, sales: 1833]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 847, sales: 4172]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 903, sales: 7281]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 891, sales: 4477]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 1036, sales: 3174]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 666, sales: 2342]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 672, sales: 5365]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 699, sales: 5072]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 803, sales: 2857]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 807, sales: 6515]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 719, sales: 3225]
# Negative Local Outlier Warning: [date: 2013-01-16, store: 714, sales: 1613]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 373, sales: 2127]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 356, sales: 2610]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 411, sales: 5128]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 407, sales: 1442]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 402, sales: 2667]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 394, sales: 4055]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 348, sales: 4677]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 298, sales: 3351]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 283, sales: 3940]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 288, sales: 2091]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 347, sales: 2052]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 342, sales: 6374]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 337, sales: 2200]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 317, sales: 2566]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 491, sales: 2989]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 497, sales: 5640]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 500, sales: 2352]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 540, sales: 1621]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 539, sales: 7670]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 434, sales: 4783]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 420, sales: 1705]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 428, sales: 3227]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 429, sales: 2090]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 430, sales: 4397]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 485, sales: 2135]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 471, sales: 3290]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 455, sales: 2575]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 457, sales: 1767]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 100, sales: 4170]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 99, sales: 1889]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 81, sales: 3591]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 129, sales: 5396]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 108, sales: 5550]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 113, sales: 4426]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 114, sales: 3063]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 115, sales: 2890]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 26, sales: 2827]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 136, sales: 2040]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 52, sales: 3754]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 51, sales: 3087]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 41, sales: 2209]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 46, sales: 2272]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 231, sales: 1872]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 215, sales: 2498]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 255, sales: 1256]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 277, sales: 3340]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 158, sales: 4405]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 174, sales: 3609]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 192, sales: 2447]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 915, sales: 3542]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 947, sales: 4829]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 952, sales: 2800]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 859, sales: 4631]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 842, sales: 7769]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 848, sales: 3305]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 851, sales: 3025]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 904, sales: 2796]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 903, sales: 6658]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 900, sales: 3000]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 879, sales: 1495]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1080, sales: 5441]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1068, sales: 1649]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1050, sales: 3901]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1094, sales: 2468]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1000, sales: 4485]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1012, sales: 2682]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1038, sales: 3792]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 1114, sales: 13618]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 650, sales: 3924]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 644, sales: 5249]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 633, sales: 3708]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 637, sales: 3434]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 684, sales: 2715]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 669, sales: 1930]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 677, sales: 3125]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 587, sales: 2983]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 584, sales: 2464]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 574, sales: 4507]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 571, sales: 3554]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 620, sales: 4111]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 611, sales: 3245]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 604, sales: 4264]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 775, sales: 4084]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 777, sales: 1764]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 804, sales: 2191]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 820, sales: 7443]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 815, sales: 5534]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 716, sales: 2939]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 714, sales: 1693]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 766, sales: 2801]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 730, sales: 6913]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 710, sales: 1799]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 706, sales: 3115]
# Negative Local Outlier Warning: [date: 2013-01-17, store: 750, sales: 1883]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 332, sales: 1176]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 315, sales: 1974]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 483, sales: 1252]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 454, sales: 1782]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 462, sales: 2138]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 88, sales: 1644]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 73, sales: 1885]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 123, sales: 3300]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 137, sales: 297]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 276, sales: 1675]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 257, sales: 3022]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 209, sales: 3412]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 921, sales: 4276]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 969, sales: 972]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 968, sales: 3193]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 945, sales: 2305]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 953, sales: 1887]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 870, sales: 4970]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 559, sales: 1496]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 840, sales: 4019]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 1045, sales: 3407]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 1032, sales: 4383]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 1029, sales: 1446]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 837, sales: 1296]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 589, sales: 829]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 594, sales: 1903]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 700, sales: 1447]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 786, sales: 712]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 817, sales: 14763]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 715, sales: 2087]
# Negative Local Outlier Warning: [date: 2013-01-19, store: 709, sales: 3111]
# Negative Local Outlier Warning: [date: 2013-01-20, store: 310, sales: 1890]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-4c17f2b32e27> in <module>()
# ----> 1 readStream(stream)
#
# <ipython-input-142-511eb03b99d0> in readStream(stream)
#       3         if(row["Open"] == 1):
#       4             # check if local outlier
# ----> 5             if(row['Sales'] < local_mean[row["Store"]]- 2 * local_std[row["Store"]]):
#       6                 print("Negative Local Outlier Warning: [date: {}, store: {}, sales: {}]".format(row['Date'],row['Store'],row['Sales']))
#       7             elif (row['Sales'] < local_mean[row["Store"]]- 2 * local_std[row["Store"]]):
#
# C:\Users\David Dupuis\Anaconda2\lib\site-packages\pandas\core\series.pyc in __getitem__(self, key)
#     601         key = com._apply_if_callable(key, self)
#     602         try:
# --> 603             result = self.index.get_value(self, key)
#     604
#     605             if not is_scalar(result):
#
# C:\Users\David Dupuis\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in get_value(self, series, key)
#    2166         k = self._convert_scalar_indexer(k, kind='getitem')
#    2167         try:
# -> 2168             return self._engine.get_value(s, k,
#    2169                                           tz=getattr(series.dtype, 'tz', None))
#    2170         except KeyError as e1:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Solution 2
#
# We train on passed data a time series classification algorithm
#
# ### Solution 2.1
#
# We only use data from train.csv.
#
# ### Solution 2.2
#
# We combine data from train.csv and store.csv into one time series dataset.
